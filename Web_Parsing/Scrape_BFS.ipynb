# %%
import requests
from bs4 import BeautifulSoup
from collections import deque

visited = set(["http://toscrape.com"])
dq = deque([["http://toscrape.com", "", 0]])
max_depth = 3

while dq:
    base, path, depth = dq.popleft()
    #                         ^^^^ removing "left" makes this a DFS (stack)

    if depth < max_depth:
        try:
            soup = BeautifulSoup(requests.get(base + path).text, "html.parser")

            for link in soup.find_all("a"):
                href = link.get("href")

                if href not in visited:
                    visited.add(href)
                    print("  " * depth + f"at depth {depth}: {href}")

                    if href.startswith("http"):
                        dq.append([href, "", depth + 1])
                    else:
                        dq.append([base, href, depth + 1])
        except:
            pass
# Out:
# at depth 0: http://books.toscrape.com
# at depth 0: http://quotes.toscrape.com/
# at depth 0: http://quotes.toscrape.com
# at depth 0: http://quotes.toscrape.com/scroll
# at depth 0: http://quotes.toscrape.com/js
# at depth 0: http://quotes.toscrape.com/js-delayed
# at depth 0: http://quotes.toscrape.com/tableful
# at depth 0: http://quotes.toscrape.com/login
# at depth 0: http://quotes.toscrape.com/search.aspx
# at depth 0: http://quotes.toscrape.com/random
#   at depth 1: index.html
#   at depth 1: catalogue/category/books_1/index.html
#   at depth 1: catalogue/category/books/travel_2/index.html
#   at depth 1: catalogue/category/books/mystery_3/index.html
#   at depth 1: catalogue/category/books/historical-fiction_4/index.html
#   at depth 1: catalogue/category/books/sequential-art_5/index.html
#   at depth 1: catalogue/category/books/classics_6/index.html
#   at depth 1: catalogue/category/books/philosophy_7/index.html
#   at depth 1: catalogue/category/books/romance_8/index.html
#   at depth 1: catalogue/category/books/womens-fiction_9/index.html
#   at depth 1: catalogue/category/books/fiction_10/index.html
#   at depth 1: catalogue/category/books/childrens_11/index.html
#   at depth 1: catalogue/category/books/religion_12/index.html
#   at depth 1: catalogue/category/books/nonfiction_13/index.html
#   at depth 1: catalogue/category/books/music_14/index.html
#   at depth 1: catalogue/category/books/default_15/index.html
#   at depth 1: catalogue/category/books/science-fiction_16/index.html
#   at depth 1: catalogue/category/books/sports-and-games_17/index.html
#   at depth 1: catalogue/category/books/add-a-comment_18/index.html
#   at depth 1: catalogue/category/books/fantasy_19/index.html
#   at depth 1: catalogue/category/books/new-adult_20/index.html
#   at depth 1: catalogue/category/books/young-adult_21/index.html
#   at depth 1: catalogue/category/books/science_22/index.html
#   at depth 1: catalogue/category/books/poetry_23/index.html
#   at depth 1: catalogue/category/books/paranormal_24/index.html
#   at depth 1: catalogue/category/books/art_25/index.html
#   at depth 1: catalogue/category/books/psychology_26/index.html
#   at depth 1: catalogue/category/books/autobiography_27/index.html
#   at depth 1: catalogue/category/books/parenting_28/index.html
#   at depth 1: catalogue/category/books/adult-fiction_29/index.html
#   at depth 1: catalogue/category/books/humor_30/index.html
#   at depth 1: catalogue/category/books/horror_31/index.html
#   at depth 1: catalogue/category/books/history_32/index.html
#   at depth 1: catalogue/category/books/food-and-drink_33/index.html
#   at depth 1: catalogue/category/books/christian-fiction_34/index.html
#   at depth 1: catalogue/category/books/business_35/index.html
#   at depth 1: catalogue/category/books/biography_36/index.html
#   at depth 1: catalogue/category/books/thriller_37/index.html
#   at depth 1: catalogue/category/books/contemporary_38/index.html
#   at depth 1: catalogue/category/books/spirituality_39/index.html
#   at depth 1: catalogue/category/books/academic_40/index.html
#   at depth 1: catalogue/category/books/self-help_41/index.html
#   at depth 1: catalogue/category/books/historical_42/index.html
#   at depth 1: catalogue/category/books/christian_43/index.html
#   at depth 1: catalogue/category/books/suspense_44/index.html
#   at depth 1: catalogue/category/books/short-stories_45/index.html
#   at depth 1: catalogue/category/books/novels_46/index.html
#   at depth 1: catalogue/category/books/health_47/index.html
#   at depth 1: catalogue/category/books/politics_48/index.html
#   at depth 1: catalogue/category/books/cultural_49/index.html
#   at depth 1: catalogue/category/books/erotica_50/index.html
#   at depth 1: catalogue/category/books/crime_51/index.html
#   at depth 1: catalogue/a-light-in-the-attic_1000/index.html
#   at depth 1: catalogue/tipping-the-velvet_999/index.html
#   at depth 1: catalogue/soumission_998/index.html
#   at depth 1: catalogue/sharp-objects_997/index.html
#   at depth 1: catalogue/sapiens-a-brief-history-of-humankind_996/index.html
#   at depth 1: catalogue/the-requiem-red_995/index.html
#   at depth 1: catalogue/the-dirty-little-secrets-of-getting-your-dream-job_994/index.html
#   at depth 1: catalogue/the-coming-woman-a-novel-based-on-the-life-of-the-infamous-feminist-victoria-woodhull_993/index.html
#   at depth 1: catalogue/the-boys-in-the-boat-nine-americans-and-their-epic-quest-for-gold-at-the-1936-berlin-olympics_992/index.html
#   at depth 1: catalogue/the-black-maria_991/index.html
#   at depth 1: catalogue/starving-hearts-triangular-trade-trilogy-1_990/index.html
#   at depth 1: catalogue/shakespeares-sonnets_989/index.html
#   at depth 1: catalogue/set-me-free_988/index.html
#   at depth 1: catalogue/scott-pilgrims-precious-little-life-scott-pilgrim-1_987/index.html
#   at depth 1: catalogue/rip-it-up-and-start-again_986/index.html
#   at depth 1: catalogue/our-band-could-be-your-life-scenes-from-the-american-indie-underground-1981-1991_985/index.html
#   at depth 1: catalogue/olio_984/index.html
#   at depth 1: catalogue/mesaerion-the-best-science-fiction-stories-1800-1849_983/index.html
#   at depth 1: catalogue/libertarianism-for-beginners_982/index.html
#   at depth 1: catalogue/its-only-the-himalayas_981/index.html
#   at depth 1: catalogue/page-2.html
#   at depth 1: /
#   at depth 1: /login
#   at depth 1: /author/Albert-Einstein
#   at depth 1: /tag/change/page/1/
#   at depth 1: /tag/deep-thoughts/page/1/
#   at depth 1: /tag/thinking/page/1/
#   at depth 1: /tag/world/page/1/
#   at depth 1: /author/J-K-Rowling
#   at depth 1: /tag/abilities/page/1/
#   at depth 1: /tag/choices/page/1/
#   at depth 1: /tag/inspirational/page/1/
#   at depth 1: /tag/life/page/1/
#   at depth 1: /tag/live/page/1/
#   at depth 1: /tag/miracle/page/1/
#   at depth 1: /tag/miracles/page/1/
#   at depth 1: /author/Jane-Austen
#   at depth 1: /tag/aliteracy/page/1/
#   at depth 1: /tag/books/page/1/
#   at depth 1: /tag/classic/page/1/
#   at depth 1: /tag/humor/page/1/
#   at depth 1: /author/Marilyn-Monroe
#   at depth 1: /tag/be-yourself/page/1/
#   at depth 1: /tag/adulthood/page/1/
#   at depth 1: /tag/success/page/1/
#   at depth 1: /tag/value/page/1/
#   at depth 1: /author/Andre-Gide
#   at depth 1: /tag/love/page/1/
#   at depth 1: /author/Thomas-A-Edison
#   at depth 1: /tag/edison/page/1/
#   at depth 1: /tag/failure/page/1/
#   at depth 1: /tag/paraphrased/page/1/
#   at depth 1: /author/Eleanor-Roosevelt
#   at depth 1: /tag/misattributed-eleanor-roosevelt/page/1/
#   at depth 1: /author/Steve-Martin
#   at depth 1: /tag/obvious/page/1/
#   at depth 1: /tag/simile/page/1/
#   at depth 1: /page/2/
#   at depth 1: /tag/love/
#   at depth 1: /tag/inspirational/
#   at depth 1: /tag/life/
#   at depth 1: /tag/humor/
#   at depth 1: /tag/books/
#   at depth 1: /tag/reading/
#   at depth 1: /tag/friendship/
#   at depth 1: /tag/friends/
#   at depth 1: /tag/truth/
#   at depth 1: /tag/simile/
#   at depth 1: https://www.goodreads.com/quotes
#   at depth 1: https://scrapinghub.com
#   at depth 1: /js/page/2/
#   at depth 1: /js-delayed/page/2/
#   at depth 1: /tableful/tag/love/page/1/
#   at depth 1: /tableful/tag/inspirational/page/1/
#   at depth 1: /tableful/tag/life/page/1/
#   at depth 1: /tableful/tag/humor/page/1/
#   at depth 1: /tableful/tag/books/page/1/
#   at depth 1: /tableful/tag/reading/page/1/
#   at depth 1: /tableful/tag/friendship/page/1/
#   at depth 1: /tableful/tag/friends/page/1/
#   at depth 1: /tableful/tag/truth/page/1/
#   at depth 1: /tableful/tag/simile/page/1/
#   at depth 1: /tableful/tag/change/page/1/
#   at depth 1: /tableful/tag/deep-thoughts/page/1/
#   at depth 1: /tableful/tag/thinking/page/1/
#   at depth 1: /tableful/tag/world/page/1/
#   at depth 1: /tableful/tag/abilities/page/1/
#   at depth 1: /tableful/tag/choices/page/1/
#   at depth 1: /tableful/tag/live/page/1/
#   at depth 1: /tableful/tag/miracle/page/1/
#   at depth 1: /tableful/tag/miracles/page/1/
#   at depth 1: /tableful/tag/aliteracy/page/1/
#   at depth 1: /tableful/tag/classic/page/1/
#   at depth 1: /tableful/tag/be-yourself/page/1/
#   at depth 1: /tableful/tag/adulthood/page/1/
#   at depth 1: /tableful/tag/success/page/1/
#   at depth 1: /tableful/tag/value/page/1/
#   at depth 1: /tableful/tag/edison/page/1/
#   at depth 1: /tableful/tag/failure/page/1/
#   at depth 1: /tableful/tag/paraphrased/page/1/
#   at depth 1: /tableful/tag/misattributed-eleanor-roosevelt/page/1/
#   at depth 1: /tableful/tag/obvious/page/1/
#   at depth 1: /tableful/page/2/
#     at depth 2: /author/Terry-Pratchett
#     at depth 2: /tag/open-mind/page/1/
#     at depth 2: /tag/friends/page/1/
#     at depth 2: /tag/heartbreak/page/1/
#     at depth 2: /tag/sisters/page/1/
#     at depth 2: /author/Elie-Wiesel
#     at depth 2: /tag/activism/page/1/
#     at depth 2: /tag/apathy/page/1/
#     at depth 2: /tag/hate/page/1/
#     at depth 2: /tag/indifference/page/1/
#     at depth 2: /tag/opposite/page/1/
#     at depth 2: /tag/philosophy/page/1/
#     at depth 2: /tag/death/page/1/
#     at depth 2: /author/George-Eliot
#     at depth 2: /author/C-S-Lewis
#     at depth 2: /tag/reading/page/1/
#     at depth 2: /tag/tea/page/1/
#     at depth 2: /author/Martin-Luther-King-Jr
#     at depth 2: /tag/hope/page/1/
#     at depth 2: /author/Helen-Keller
#     at depth 2: /tag/inspirational/page/2/
#     at depth 2: /author/Douglas-Adams
#     at depth 2: /tag/navigation/page/1/
#     at depth 2: /author/Mark-Twain
#     at depth 2: /tag/contentment/page/1/
#     at depth 2: /tag/friendship/page/1/
#     at depth 2: /author/Allen-Saunders
#     at depth 2: /tag/fate/page/1/
#     at depth 2: /tag/misattributed-john-lennon/page/1/
#     at depth 2: /tag/planning/page/1/
#     at depth 2: /tag/plans/page/1/
#     at depth 2: /author/Dr-Seuss
#     at depth 2: /tag/comedy/page/1/
#     at depth 2: /tag/yourself/page/1/
#     at depth 2: /author/George-Bernard-Shaw
#     at depth 2: /author/Ralph-Waldo-Emerson
#     at depth 2: /tag/regrets/page/1/
#     at depth 2: /tag/life/page/2/
#     at depth 2: /author/Jorge-Luis-Borges
#     at depth 2: /tag/library/page/1/
#     at depth 2: /author/Haruki-Murakami
#     at depth 2: /tag/thought/page/1/
#     at depth 2: /author/Ernest-Hemingway
#     at depth 2: /tag/novelist-quotes/page/1/
#     at depth 2: /author/J-D-Salinger
#     at depth 2: /tag/authors/page/1/
#     at depth 2: /tag/literature/page/1/
#     at depth 2: /tag/writing/page/1/
#     at depth 2: /author/Madeleine-LEngle
#     at depth 2: /tag/children/page/1/
#     at depth 2: /tag/difficult/page/1/
#     at depth 2: /tag/grown-ups/page/1/
#     at depth 2: /tag/write/page/1/
#     at depth 2: /tag/writers/page/1/
#     at depth 2: /tag/books/page/2/
#     at depth 2: /author/Garrison-Keillor
#     at depth 2: /tag/religion/page/1/
#     at depth 2: /author/Jim-Henson
#     at depth 2: /author/Charles-M-Schulz
#     at depth 2: /tag/chocolate/page/1/
#     at depth 2: /tag/food/page/1/
#     at depth 2: /author/Suzanne-Collins
#     at depth 2: /author/Charles-Bukowski
#     at depth 2: /author/George-Carlin
#     at depth 2: /tag/insanity/page/1/
#     at depth 2: /tag/lies/page/1/
#     at depth 2: /tag/lying/page/1/
#     at depth 2: /tag/self-indulgence/page/1/
#     at depth 2: /tag/truth/page/1/
#     at depth 2: /tag/humor/page/2/
#     at depth 2: /author/Bob-Marley
#     at depth 2: /author/Friedrich-Nietzsche
#     at depth 2: /tag/lack-of-friendship/page/1/
#     at depth 2: /tag/lack-of-love/page/1/
#     at depth 2: /tag/marriage/page/1/
#     at depth 2: /tag/unhappy-marriage/page/1/
#     at depth 2: /author/Pablo-Neruda
#     at depth 2: /tag/poetry/page/1/
#     at depth 2: /tag/girls/page/1/
#     at depth 2: /author/James-Baldwin
#     at depth 2: /tag/love/page/2/
